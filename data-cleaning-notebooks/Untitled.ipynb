# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#import missingno

# %%
full_df = pd.read_csv('../data/bom_imdb_revenue_concatenated.csv')

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7846 entries, 0 to 7845
# Data columns (total 6 columns):
# Unnamed: 0     7846 non-null int64
# title          7846 non-null object
# year           7846 non-null int64
# dom_gross      7818 non-null float64
# for_gross      6492 non-null float64
# world_gross    6464 non-null float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 367.9+ KB

# %%
df.loc[(df['dom_gross'] == 0.0) | (df['for_gross'] == 0.0)]
# Out:
#       Unnamed: 0                                           title  year  \
# 3473        3581                                        Moonfall  2020
# 3560        3728                     Men in Black: International  2019
# 3656        3866                                          Bright  2017
# 3657        3867                                Army of the Dead  2019
# 3677        3892                                  102 Dalmatians  2000
# 3685        3902                                  Meet Joe Black  1998
# 3702        3922                                Call of the Wild  2020
# 3739        3971                                Mighty Joe Young  1998
# 3764        4004  Ast̩rix et Ob̩lix: Au service de Sa Majest̩  2012
# 3765        4006                                       Renegades  2019
# 3782        4030                                Inspector Gadget  1999
# 3795        4046                               Anna and the King  1999
# ...

# %%
df1 = df1.drop(df[(df['dom_gross'] == 0.0) | (df['for_gross'] == 0.0)].index)

# %%
df1.shape
# Out:
# (6110, 6)
